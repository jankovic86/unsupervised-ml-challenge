# %%
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import pandas as pd
file = Path('Resources/crypto_data.csv')

# %%
crypto_df = pd.read_csv(file)
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Filter for currencies that are currently being traded.
traded_crypto = crypto_df[crypto_df["IsTrading"] == True]
traded_crypto = traded_crypto.rename(columns = {"Unnamed: 0":"Symbol"})
traded_crypto
# Out:
#      Symbol     CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1       365      365Coin          X11       True   PoW/PoS              NaN
# 2       404      404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       611    SixEleven      SHA-256       True       PoW              NaN
# 4       808          808      SHA-256       True   PoW/PoS     0.000000e+00
# ...     ...          ...          ...        ...       ...              ...
# 1243   SERO   Super Zero       Ethash       True       PoW              NaN
# 1244    UOS          UOS      SHA-256       True      DPoI              NaN
# 1245    BDX       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       True       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# ...

# %%
# Remove the IsTrading Column
traded_df = traded_crypto.drop(columns=["IsTrading"])
traded_df
# Out:
#      Symbol     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1       365      365Coin          X11   PoW/PoS              NaN
# 2       404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3       611    SixEleven      SHA-256       PoW              NaN
# 4       808          808      SHA-256   PoW/PoS     0.000000e+00
# ...     ...          ...          ...       ...              ...
# 1243   SERO   Super Zero       Ethash       PoW              NaN
# 1244    UOS          UOS      SHA-256      DPoI              NaN
# 1245    BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# ...

# %%
# Remove all rows that have at least one null value.
for column in traded_df.columns:
    print(f"Column {column} has {traded_df[column].isnull().sum()} null values")
# Out:
# Column Symbol has 0 null values
# Column CoinName has 0 null values
# Column Algorithm has 0 null values
# Column ProofType has 0 null values
# Column TotalCoinsMined has 459 null values
# Column TotalCoinSupply has 0 null values

# %%
no_null_df = traded_df.dropna()
no_null_df
# Out:
#      Symbol     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2       404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4       808          808      SHA-256   PoW/PoS     0.000000e+00
# 5      1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7       BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...     ...          ...          ...       ...              ...
# 1238   ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242    GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245    BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...              ...
# 1238      2000000000
# ...

# %%
# Filter for cryptocurrencies that have been mined.
mined_df = no_null_df[no_null_df["TotalCoinsMined"] > 0]
mined_df
# Out:
#      Symbol     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0        42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2       404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5      1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7       BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8       ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...     ...          ...          ...       ...              ...
# 1238   ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242    GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245    BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246    ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247    XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# 1238      2000000000
# ...

# %%
clean = mined_df.drop(columns=["CoinName"])
clean_df = clean.set_index("Symbol")
clean_df
# Out:
#           Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Symbol
# 42           Scrypt   PoW/PoS     4.199995e+01              42
# 404          Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337            X13   PoW/PoS     2.927942e+10    314159265359
# BTC         SHA-256       PoW     1.792718e+07        21000000
# ETH          Ethash       PoW     1.076842e+08               0
# ...             ...       ...              ...             ...
# ZEPH        SHA-256      DPoS     2.000000e+09      2000000000
# GAP          Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX     CryptoNight       PoW     9.802226e+08      1400222610
# ZEN        Equihash       PoW     7.296538e+06        21000000
# XBC          Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# Convert the remaining features with text values, Algorithm and ProofType, into numerical data.
dummies_df = pd.get_dummies(clean_df, columns=["Algorithm", "ProofType"])
dummies_df
# Out:
#         TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Symbol
# 42         4.199995e+01              42                                 0
# 404        1.055185e+09       532000000                                 0
# 1337       2.927942e+10    314159265359                                 0
# BTC        1.792718e+07        21000000                                 0
# ETH        1.076842e+08               0                                 0
# ...                 ...             ...                               ...
# ZEPH       2.000000e+09      2000000000                                 0
# GAP        1.493105e+07       250000000                                 0
# BDX        9.802226e+08      1400222610                                 0
# ZEN        7.296538e+06        21000000                                 0
# XBC        1.283270e+05         1000000                                 0
#
# ...
